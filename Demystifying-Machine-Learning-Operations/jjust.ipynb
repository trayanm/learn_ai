# %%
import matplotlib.pyplot as plt

plt.plot([1, 2, 3, 4], [6, 18, 22, 43])
plt.title('Sample Plot')
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.show()

# %%
import pandas as pd

owners = ["Peter", "Sara", "Ali", "John"]
data = {"cars": [5, 4, 1, 7], "boats": [6, 2, 0, 2]}

vehicles = pd.DataFrame(data, index=owners)
